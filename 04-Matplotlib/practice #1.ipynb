# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.arange(0,10)

# %%
y = 2*x

# %%
plt.plot(x,y)
plt.xlabel('Os. x')
plt.ylabel('Os y')
plt.xlim(0,6)
plt.ylim(0,20)
plt.title('Sosy chlen')
plt.savefig('MyFirstPlot.png')
